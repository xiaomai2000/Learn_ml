# %%
# This is pandas execise part 3, maining focus on:
#     Grouping and filttering
# Date: 2020-10-04

# %%
import pandas as pd

# %%
url = '.\chipotle.csv'
chipo = pd.read_csv(url, sep='\t')

# %%
# summary
chipo.describe(include='all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   3373.000000  3373.000000          3373               2477       3373
# unique          NaN          NaN            49                872         66
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           518                 97        520
# mean     678.825082     1.066113           NaN                NaN        NaN
# std      384.273447     0.293391           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      346.000000     1.000000           NaN                NaN        NaN
# 50%      683.000000     1.000000           NaN                NaN        NaN
# 75%     1006.000000     1.000000           NaN                NaN        NaN
# max     1353.000000     5.000000           NaN                NaN        NaN

# %%
# Filttering 1

#select cost > 10 

prices = [ float(value[1 : -1]) for value in chipo.item_price   ]


# Reassign the column with new "float"  value
chipo.item_price = prices

# %%
# remove duplicated item_name and quantity
chipo_filtered = chipo.drop_duplicates(['item_name','quantity'])

# select only the products with quantity = 1
chipo_one_prod = chipo_filtered[chipo_filtered.quantity ==1]
chipo_one_prod[chipo_one_prod['item_price']>10].item_name.nunique()
# Out:
# 12

# %%
#
SelectName = 'Chicken Soft Tacos'
chipo[ chipo['item_name'] == SelectName ]
# Out:
#       order_id  quantity           item_name  \
# 12           6         1  Chicken Soft Tacos
# 35          18         1  Chicken Soft Tacos
# 36          18         1  Chicken Soft Tacos
# 75          34         1  Chicken Soft Tacos
# 79          35         1  Chicken Soft Tacos
# ...        ...       ...                 ...
# 3071      1223         1  Chicken Soft Tacos
# 3160      1261         1  Chicken Soft Tacos
# 3243      1298         1  Chicken Soft Tacos
# 3279      1315         1  Chicken Soft Tacos
# 3290      1320         1  Chicken Soft Tacos
#
#                                      choice_description  item_price
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...        8.75
# 35                     [Roasted Chili Corn Salsa, Rice]        8.75
# 36        [Roasted Chili Corn Salsa, [Cheese, Lettuce]]        8.75
# 75    [Tomatillo Red Chili Salsa, [Rice, Cheese, Sou...        8.75
# 79    [Roasted Chili Corn Salsa, [Rice, Cheese, Lett...       11.25
# ...

# %%
chipo.item_name.sort_values().tail(100).head(20)
# Out:
# 1319       Veggie Bowl
# 619        Veggie Bowl
# 2084    Veggie Burrito
# 57      Veggie Burrito
# 2685    Veggie Burrito
# 1105    Veggie Burrito
# 497     Veggie Burrito
# 2096    Veggie Burrito
# 631     Veggie Burrito
# 623     Veggie Burrito
# 2911    Veggie Burrito
# 1959    Veggie Burrito
# 3234    Veggie Burrito
# 931     Veggie Burrito
# 1038    Veggie Burrito
# 3367    Veggie Burrito
# 535     Veggie Burrito
# 1497    Veggie Burrito
# 2755    Veggie Burrito
# 2280    Veggie Burrito
# Name: item_name, dtype: object

# %%
chipo.sort_values(by='item_price', ascending = True)
# Out:
#       order_id  quantity        item_name  \
# 200         89         1      Canned Soda
# 1396       567         1      Canned Soda
# 317        138         1      Canned Soda
# 2850      1132         1      Canned Soda
# 1030       424         1      Canned Soda
# ...        ...       ...              ...
# 3334      1336         3       Steak Bowl
# 1514       616         3     Chicken Bowl
# 1255       511         3    Steak Burrito
# 409        178         3     Chicken Bowl
# 1254       511         4  Chicken Burrito
#
#                                      choice_description  item_price
# 200                                         [Diet Coke]        1.09
# 1396                                        [Coca Cola]        1.09
# 317                                         [Diet Coke]        1.09
# 2850                                        [Diet Coke]        1.09
# 1030                                  [Diet Dr. Pepper]        1.09
# ...

# %%
#How many "Chicken Bowl"
chipo_chicken = chipo[chipo.item_name == 'Chicken Bowl']
len(chipo_chicken)

# %%
# Find all food like 'Chicken%'
chipo_like_chicken = chipo[chipo.item_name.str.startswith('Chicken')]
chipo_like_chicken
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# ...        ...       ...                   ...
# 3363      1349         1         Chicken Salad
# 3365      1350         1          Chicken Bowl
# 3369      1352         1       Chicken Burrito
# 3371      1353         1       Chicken Burrito
# 3372      1353         1  Chicken Crispy Tacos
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...        8.75
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...        8.75
# ...
