# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = 20 * np.random.randn(10000)
plt.hist(x, 20, range=(-50,50), histtype = 'stepfilled', align='mid', color='b', 
         label='Test Histogram')
plt.legend()
plt.title('Step Filled Histogram')
plt.show()

# %%
print(x.max(), x.min(), x.mean())
# Out:
# 86.4405848632171 -76.65884127161105 0.20658612276927585

# %%
spread = 100 * np.random.rand(100)
center = np.ones(50) * 50
flier_high = 100 * np.random.rand(10) + 100 
flier_low = -100 * np.random.rand(10)
data = np.concatenate((spread, center, flier_high, flier_low))

# %%
plt.boxplot(data, sym='rx', widths=0.25, notch=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x247c6705f48>,
#   <matplotlib.lines.Line2D at 0x247c6705ec8>],
#  'caps': [<matplotlib.lines.Line2D at 0x247c66f0d48>,
#   <matplotlib.lines.Line2D at 0x247c66f0cc8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x247c6705488>],
#  'medians': [<matplotlib.lines.Line2D at 0x247c6b43cc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x247c6b43c48>],
#  'means': []}

# %%
print(spread)
# Out:
# [79.32303249 72.12220207 26.10708119 72.81463796 21.16899218 36.33777122
#  10.71606996 88.92848954 99.09609339 36.93358269 74.90659504  3.24405425
#  26.79022984 21.18693682 96.92125378 61.67076112 83.95867707 86.07883827
#  93.68184331  2.56131572 50.58199046 62.95061016 57.73558244 11.22846021
#  90.60175775 16.14863752 12.08957413 91.41936273 47.6093124  86.193081
#  37.81057749 77.28824098 26.16138121 86.42445359 58.13252237 34.03503549
#  33.39736264 16.97038884 10.07643111 55.17813771 25.48884824 19.08477041
#  20.19060486  9.65977667 78.11307689 88.81923362 19.05457951 58.87428
#  91.29698773 45.65102718 64.74763823 29.83948082 60.52913604 99.46899265
#  10.90563013 55.20774115 98.80587406 94.08930936 79.80360995 30.74646616
#  56.96585673  7.24672646 46.24473811  3.02221217 45.90283136 36.52469718
#  85.36289695 20.02256192 84.01340771 60.90633863 85.55018128 42.08355588
#   2.15972429 13.18951621 70.4630789  89.22080421 87.86611849 12.51348847
#  72.33784552 89.05853721 97.80120728 25.98855738 30.45966137 76.39685912
#  18.75546577 70.74011306 91.72179491 53.80454218 47.39405217 63.12847114
#  90.77474826 56.64882763 93.564968   86.68815034 25.37675934 26.90823038
#  77.16195138 83.1430597  54.3994065  63.33104734]

# %%
x1 = 5 * np.random.rand(40)
x2 = 5 * np.random.rand(40) + 25
x3 = 25 * np.random.rand(20)

x = np.concatenate((x1,x2,x3))

y1 = 5 * np.random.rand(40)
y2 = 5 * np.random.rand(40) + 25
y3 = 25 * np.random.rand(20)
y = np.concatenate((y1, y2, y3))

color_array = ['b']*50 + ['g']*25 + ['r']*25

plt.scatter(x, y, s=[100], marker='^', c=color_array)

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x, p(x), 'm-')

plt.show()
